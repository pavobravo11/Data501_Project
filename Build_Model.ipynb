# %%
import pandas as pd
import matplotlib.pyplot as plt
from seaborn import boxplot

# %%
countries = pd.read_excel("European Countries.xlsx")
msci = pd.read_csv("governance/MSCI Ratings Aggregated.csv")
ccpi = pd.read_csv("Environmental/ccpi_2024.csv")

# %%
model = pd.merge(countries, msci, on = 'Country', how = 'left').merge(ccpi, on = 'Country', how = 'left')

# %%
model.head()
# Out:
#                   Country         Subregion  Poplation  \
# 0                 Albania  Southeast Europe    2837743
# 1                 Austria    Central Europe    8917205
# 2                 Belarus    Eastern Europe    9398861
# 3                 Belgium    Western Europe   11555997
# 4  Bosnia and Herzegovina  Southeast Europe    3280815
#
#   European Union Association  MSCI_IVA_Adjusted_Mean  MSCI_AGR_Var_Mean  \
# 0             No Association                     NaN                NaN
# 1        European Union (EU)                7.861111           5.129630
# 2             No Association                     NaN                NaN
# 3        European Union (EU)                7.961538           4.899083
# 4             No Association                     NaN                NaN
#
#    MSCI_Governance_Score_Mean  2024_CCPI_GHG  2024_CCPI_Renewables  \
# 0                         NaN            NaN                   NaN
# 1                    6.848649         61.075                  44.6
# 2                         NaN         62.300                  16.2
# 3                    6.620370         63.225                  31.3
# 4                         NaN            NaN                   NaN
#
#    2024_CCPI_Energy_Use  2024_CCPI_Climate_Policy
# 0                   NaN                       NaN
# 1                 54.75                     69.35
# 2                 68.90                     24.30
# 3                 52.75                     64.50
# 4                   NaN                       NaN

# %%
model.to_excel("Current_Model_Build.xlsx", index=False)

# %%
model.dropna(how='any').head()
# Out:
#     Country        Subregion  Poplation European Union Association  \
# 1   Austria   Central Europe    8917205        European Union (EU)
# 3   Belgium   Western Europe   11555997        European Union (EU)
# 9   Denmark  Northern Europe    5831404        European Union (EU)
# 11  Finland  Northern Europe    5530719        European Union (EU)
# 12   France   Western Europe   67391582        European Union (EU)
#
#     MSCI_IVA_Adjusted_Mean  MSCI_AGR_Var_Mean  MSCI_Governance_Score_Mean  \
# 1                 7.861111           5.129630                    6.848649
# 3                 7.961538           4.899083                    6.620370
# 9                 8.444444           4.867257                    7.920755
# 11                8.979167           4.690141                    7.712000
# 12                8.165714           4.855478                    6.725000
#
#     2024_CCPI_GHG  2024_CCPI_Renewables  2024_CCPI_Energy_Use  \
# 1          61.075                 44.60                 54.75
# 3          63.225                 31.30                 52.75
# 9          74.500                 75.05                 67.65
# 11         63.450                 66.95                 22.45
# 12         67.550                 22.75                 64.20
#
#     2024_CCPI_Climate_Policy
# 1                      69.35
# 3                      64.50
# 9                      86.20
# 11                     89.30
# 12                     63.55
